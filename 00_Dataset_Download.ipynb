# %% [markdown]
# <a href="https://colab.research.google.com/github/Niharikkaa/Smart-grid-theft-detection/blob/main/00_Dataset_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-82910350-b6c1-44b9-ba15-54a463db9ab5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82910350-b6c1-44b9-ba15-54a463db9ab5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s "sgcc electricity theft"
# Out:
# ...
# ref                                                       title                                           size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------------  ----------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# bensalem14/sgcc-dataset                                   SGCC Electricity Theft Detection            53689905  2023-09-29 11:44:18.270000           3631         33                1
# chabdullah31222/sgcc-electricity-theft-detection-dataset  sgcc electricity theft detection dataset    95722831  2025-08-03 09:27:09.203000            354          2             0.75
# walagooose/sgcc-after-processing                          SGCC-after-processing                      100527741  2024-05-03 15:10:23.507000            219          1        0.5294118

# %%
# !kaggle datasets download -d chabdullah31222/sgcc-electricity-theft-detection-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/chabdullah31222/sgcc-electricity-theft-detection-dataset
# License(s): apache-2.0
# ...
# 100% 91.3M/91.3M [00:00<00:00, 194MB/s]

# %%
# !unzip -o sgcc-electricity-theft-detection-dataset.zip
# Out:
# Archive:  sgcc-electricity-theft-detection-dataset.zip
#   inflating: README.md
#   inflating: data.csv
#   inflating: data.z01
#   inflating: data.z02
